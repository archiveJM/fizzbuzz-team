# %% [markdown]
# # 개요

# %% [markdown]
# 여러분이 생각해봐야 할 기본적인 상황입니다.
#
# - 패스트캠퍼스의 비즈니스 모델은 어떻게 될까요?
# - 사람들은 패스트캠퍼스의 강의를 어떻게 알게 될까요?
# - 패스트캠퍼스에서 강의를 결제하는 과정은 어떻게 될까요?
# - 유저들이 강의를 구매하는 과정을 어떻게 기록할까요?
# - 결제가 된 내역은 어떻게 관리할까요?

# %% [markdown]
# **제안하는 주제들은 다음과 같습니다.**
#
# 1. EDA : 강의 구매내역을 가지고 마케팅팀과 콘텐츠 기획팀이 어떤 방향으로 강의를 제작할 수 있을지 아이디어를 제공해주세요.
# 2. 고객군 분석 : 패스트캠퍼스에서 강의를 구매하는 사람들은 어떤 그룹으로 분류될지 고민해보세요. 그룹으로 나뉘게 된다면, 해당 그룹은 어떤 특징을 가지고 있나요?
# 3. 구매 내역 분석 : 사람들은 어떤 강의를 많이 구매할까요? 사람들의 구매 패턴을 파악해보고, 마케팅이 효과가 있었는지 특정 그룹에게 해당 상품이 효과가 있는지 등을 파악해보세요.
#
# - 소소한 프로젝트 진행 Tip.
#     - kaggle에서 거래 내역을 기반으로 분석한 EDA notebook들을 살펴보세요.
#     - 최대한 많은 그래프를 그려보세요.
#     - 최대한 다양한 통계량을 계산해보세요.
#     - 내가 진짜 회사에서 Data Scientist라면? 내가 Performance Marketer라면? 실제 액션 플랜을 상상해보세요.
#     - 프로젝트의 목적에 대해서 생각해보세요. 데이터 분석 라이브러리 연습을 많이 하고 싶은지, 분석 인사이트를 키우고 싶은지.

# %% [markdown]
# 안녕하세요, 이어드림스쿨입니다 🙌
#
# 이번 **‘이어드림스쿨 2기 과정'**에서 진행될 **미니 프로젝트 : 데이터분석**에 대해 안내해드리고자 합니다 ☺️
#
# 💡 **프로젝트 개요**
#
# - 기간: 2022년 5월 9일 → 2022년 5월 23일
# - 진행 장소: 온라인(`**ZEP**`), 오프라인
# - 목적: 인공지능 중급 단계로 넘어가기 전 Python 모듈에 대한 학습이 잘 이루어졌는지 점검함과 동시에, 기업의 실제 데이터를 다루어보는 경험을 통해 심화 학습을 할 수 있습니다.
# - 평가에 포함되지 않으니, **스스로 혹은 팀원들끼리 문제를 해결해보는 경험을 하는 것이 중요합니다!**
# - 프로젝트는 기존 그룹 스터디 조로 진행해주세요.
# - 초급 분들은 강사님과 실습코치 분들이 주기적으로 도움을 드리겠습니다.
#
# ---
#
# 💡 **프로젝트 안내사항**
#
# - **데이터**: **2021.03.29~2021.09.26 패스트캠퍼스 온라인 강의 결제 내역 데이터**를 제공합니다. (약 10만개)
#
#
#     | columns |
#     | --- |
#     | id |
#     | customer_id |
#     | course_id |
#     | type |
#     | state |
#     | course_title |
#     | category_title |
#     | format |
#     | completed_at |
#
#     | transaction_amount |
#     | --- |
#     | coupon_title |
#     | coupon_discount_amount |
#     | sale_price |
#     | tax_free_amount |
#     | pg |
#     | method |
#     | subcategory_title |
#     | marketing_start_at |
# - **주제**: 아래의 프로젝트 주제 예시를 참고하여 주제를 선정해주세요. 자유롭게 주제를 선정하셔도 좋습니다!
# - 프로젝트 진행 중, 중간 보고(**`아이데이션`**) 2회가 계획되어 있습니다.
# - **`최종 발표`**(**5/23**)는 당일에 랜덤 5개의 팀을 뽑아 발표합니다.
# **(각 팀의 발표 여부는 미리 알 수 없으니 모든 팀이 발표 준비까지 마쳐야 합니다!)**
#
# ---
#
# 💡 **프로젝트 주제 예시**
#
# 여러분은 **`패스트캠퍼스`**의 **`데이터 사이언티스트`**입니다. 아래의 주제 예시를 참고해서 주제를 설계해보세요🙌
#
# 1. **고객군 분석** : **`패스트캠퍼스에서 강의를 구매하는 사람들은 어떤 그룹으로 분류될까요?`** 각자의 기준을 제시하고, 기준대로 그룹을 만들어서 특징을 파악해 보세요.
#
#
# 2. **콘텐츠 기획 분석** : **`사람들은 어떤 콘텐츠를 많이 구매할까요?`** 마케팅 효과가 있는지, 특정 그룹의 상품이 효과가 있는지 등을 확인해보세요.
#
#
# 3. **EDA** : 해당 데이터에서 인사이트를 찾아서 공유해주세요. 이 데이터를 통해 마케팅팀이, 콘텐츠 기획팀이 어떤 일을 추가로 하면 좋을지 알려주세요.
#
# ---
#
# 💡 **프로젝트 일정**
#
# - 예정되어있는 일정이며, 변경될 수 있습니다.

# %%
# 5/13 1차 아이데이션 제출
# 5/20 2차 아이데이션 제출
# 5/23 프로젝트 발표

# %% [markdown]
# **id ( PK, FK )**

# %%
# int 형식
# 고유값 사용

# %% [markdown]
# **customer_id ( PK, FK 빈값 있어 불가  )**

# %%
# int 형식
# 고유값 사용

# %% [markdown]
# **course_id ( PK, FK 빈값 있어 불가 )**

# %%
# int 형식
# 고유값 사용

# %% [markdown]
# **type ( PK, FK )**
#
# ORDER
#
# PAYMENT
#
# REFUND
#
# TRANSACTION ( 3rows )

# %%
# str 형식
# 전체 데이터에서 3건의 TRANSACTION 데이터 가 있음

# %% [markdown]
# **state ( PK, FK )**
#
# CANCELLED
#
# COMPLETED
#
# DELETED
#
# PENDING
#
# REQUESTED

# %%
# str 형식

# %% [markdown]
# **course_title ( 빈값 있음 )**

# %%
# str 형식

# %% [markdown]
# **category_title ( 빈값 있음 )**

# %%
# str 형식
# course_title이 빈 값일 때 전부 빈값

# %% [markdown]
# **format ( 빈값 있음 )**

# %%
# str 형식
# format 빈값인 경우 아래 컬럼들은 빈값이다.
# course_id, course_title, category_title, coupon_title, coupon_discount_amount,
# sale_price, tax_free_amount, pg, subcategory_title, marketing_start_at

# 위의 경우
# type 컬럼은 PAYMENT, TRANSACTION 만 존재
# state 컬럼의 값은 DELETED, COMPLETED 존재
# course_title 컬럼의 빈값의 수와 format의 빈값의 수가 일치

# 위 내용을 바탕으로 format이 없을 경우 삭제된 강의라고 유추 할 수 있다.
# 그러므로 정상 운영중인 강의는 format은 필수 항목이다.

# %% [markdown]
# **completed_at  (Not null)**

# %%
# date 형식

# %% [markdown]
# **transaction_amount ( Not Null )**

# %%
# int 형식

# %% [markdown]
# **coupon_title  ( 빈값 있음 )**

# %%
# str 형식
# 빈값일 때 coupon_discount_amount 값 없음

# %% [markdown]
# **coupon_discount_amount  ( 빈값 있음 )**

# %%
# int 형식
# 빈값일때 coupon_title 값 없음

# %% [markdown]
# sale_price  ( 빈값 있음 )

# %%
# int 형식
# 빈값일때  coupon_title, coupon_discount_amount, tax_free_amount, pg 값 없음

# %% [markdown]
# **tax_free_amount  ( 빈값 있음 )**

# %%
# int 형식
# 위와 동일

# %% [markdown]
# **pg  ( 빈값 있음 )**

# %%
# 대부분의 항목이 빈 값

# %% [markdown]
# **method ( 빈값 있음 )**

# %%
# str 형식
# 빈값일 때 pg 빈값이 없음

# %% [markdown]
# **subcategory_title  ( 빈값 있음 )**

# %%
# str 형식

# %% [markdown]
# **marketing_start_at  ( 빈값 있음 )**

# %%
# date 형식

# %% [markdown]
# # 김용담 강사님 답변

# %% [markdown]
# id : Dtype : int 추정(이하 추정 추가하지 않음) / 어떤 id인지 확인 필요 / 중복 여부 확인 / unique한 건가요?
# ```
# => 네. TransactionID 같은 느낌입니다. (각 거래내역에 대한 ID)
# ```
# customer_id : Dtype: int / 어떤 고객 id 인지, 중복 있음. / 1대다수적인지
# ```
# => 중복이 있습니다. 왜냐면 같은 고객이 여러 강의를 결제할 수 있습니다.
# (물론 그거말고 취소 내역까지 포함하면 더 많은 경우)
# ```
# course_id : Dtype: int / 빈 곳이 있던데 이유가? / 강의의 자체적 id번호 인 건지 다른 건지
# ```
# => 강의 자체의 id이고, 비어있는 값은 추가 확인이 필요할 것 같습니다.
# (저의 추측으로는 데이터를 추출할 당시에 폐기된 강의가 아닐까..)
# ```
#
#
# type : Dtype: vchar OR string / order와 payment 기준 -> 고객이 낸 건지 다른 건지
# ```
# => order는 결제 페이지까지는 갔지만, 아직 결제하지 않은 상태(흔히
# 얘기하는 장바구니에 담음)이고, payment는 최종 결제가 일어난 상태입니다.
# ```
# state : Dtype: varchar OR string  / CANCELLED : 결제가 취소된 상황, PENDING : pg사에서 결제 완료가 안된 상태, DELETED : 테이블에서 제거를 해야하는 상태 -> COMPLETE : pg 처리까지 완료된 상태 맞나요?
# ```
# => 네 맞습니다.
# ```
#
# course_title : Dtype: varchar OR string  / 패키지와 아닌 것, 프로모션인 것 과 아닌 것 한정판매 및 프리패스, 평생소장 등의 기준을 잡고 분석하는 게 좋을까요?
# ```
# => 말씀하신것처럼 강의 기획별로 해도 좋고, 분야별(e.g. UX/UI, 프론트앤드
# 등..)로 분석하는것도 방법입니다.
# ```
# category_title : Dtype: varchar OR string  / 카테고리적 분류인 건지?
# ```
# => 네 맞습니다. 대분류 느낌입니다.
# ```
#
# format : Dtype: varchar OR string  / 올인원, 스쿨 온라인, 온라인 완주반, RED 등 나누는 기준도 따로 있을까요?
# ```
# => 이거는 강의 기획 당시에 어떤 형태로 만들었냐의 차이입니다. 올인원은
# 지금의 초격차 패키지랑 같은 컨셉이고, 온라인 완주반, The RED도 다른 형태의 기획 강의입니다.
# ```
# completed_at : Dtype: date / 완료로 치는 기준, 강사분의 마지막 업로드 기준인지?
# ```
# => 결제 완료 시점입니다. 지금 이 데이터는 강의에 관련된 내용은 전혀 없고,
# 거래 내역 데이터입니다.
# ```
# transaction_amount : Dtype: int / 총 금액인 건지, 총 금액 중 할인 등이 없는 가장 처음 책정된 금액인지
# ```
# => transaction이 거래 내역이라는 의미입니다. 최종 결제 금액입니다.
# ```
#
# coupon_title : Dtype: varchar OR string /  단발성 쿠폰인지 아닌지 여부 및 한 강의만 적용되는 건지 여러번 되는 건지
# ```
# => 보통 coupon을 발행할 때는 강의별로 만드는건 아니고, 쿠폰의 효과가
# 적용된 다른 entity입니다. 여러 강의에 적용될 수 있습니다. 하지만 실제 coupon_id는 다르겠죠.
# ```
# coupon_discount_amount : Dtype: int / 강의 한 편당 할인 금액인지 전체 할인 금액인지
# ```
# => 해당 row가 어떤 단위로 정의되었는지 고민해보시면 아실 수 있을 겁니다.
# ```
# (그리고 퍼센트 할인이라고 하면, 전체에 하든 개별로 하든 같습니다)
# sale_price : Dtype: 마찬가지, 전체적 할인 금액인지, 쿠폰을 써야만 활성화 되는 등의 조건적 활성화 금액인건지
# ```
# => 쿠폰 말고도 이벤트 같은 다른 조건에 의한 할인도 있습니다. (데이터에 나와있음)
# ```
#
# tax_free_amount : Dtype: int / transaction 기준인 건지 할인 및 추가적 적용 이후 금액인지
# ```
# => 원래는 VAT를 제외한 금액이어야 하는데, 주어진 데이터에서는 다 같습니다.
# ```
#
# pg : Dtype: pg 가 무슨 단어의 약자인지 부터 기준 궁금합니다. 비어있는데 꼭 필요한 컬럼인지, 무슨 데이터 타입인건지..
# ```
# =>  PG(Payment Gateway)라고 해서 실제로 온라인 거래할 때 사용하는
# 금융거래 대행사를 의미합니다.(e.g. 카카오페이, 토스페이먼트, U+ pay 등..)
# 비어있는 것은 default PG사를 의미합니다. (LG U+ 같은 언급이 안되어있는 다른 회사중에 하나)
# ```
# method : Dtype: varchar OR string / VBANK : 가상계좌 CARD의 의미 및 기준.
# 신용카드/체크카드 등. 구분 필요한지. -> 가상계좌라는 것이 계좌이체 및 네이버페이 등 이런 류를 모두 포함하는 건가요?
# ```
# => 아닙니다. 가상계좌를 통한 결제 방법을 의미합니다.
# 일반적인 다른 온라인 결제에서 통용되는 것과 같습니다.
# ```
#
# subcategory_title : Dtype: varchar OR string / 서브 카테고리라고 되어있는데 category_title의 하위적 분류인 건지 별도인건지 체크 필요.
# ```
# => 하위 분류가 맞습니다.
# ```
#
# marketing_start_at : Dtype: date / 마케팅 기준, 쿠폰인 건지 패키지인건지 등 기준 필요. 해당의 종료일도 필요한지.
# ```
# => 해당 강의의 마케팅이 시작된 기준입니다. 여기서 마케팅은
# 해당 강의를 판매한 시점이라고 생각하시면 됩니다. (즉, landing page가 최초로 올라간 시점)
# ```

# %% [markdown]
# # Data Loading & Preprocessing

# %% [markdown]
# ##### 2022.05.18. 오전 log by 이정훈
#
# 정새롬님 데이터를 merge하였으며, 각자 목차에 맞게 내용을 채울 수 있도록 index를 명확하게 구분하였음.
#
# 참고하여서 코드 및 자료 작성하셨으면 좋겠습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
pwd
# Out:
# '/Users/Kimdaseul/Documents/dev/fizzbuzz-team/LJH'

# %% [markdown]
# ## Import raw data file[xlsx]

# %%
# !pip install openpyxl
df_o = pd.read_excel("./dataanalysisproject_rawdata.xlsx")

# %% [markdown]
# ## Preprocessing data [이정훈님 part]

# %%
# 데이터 로딩 확인
df_o.head()
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format        completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원 2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# ...

# %%
df_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
# ...

# %% [markdown]
# customer_id, course_id,course_title, category_title, format, subcategory_title의 결측치 존재하며, 나머지 데이터의 결측의 경우, 해당사항이 아예 없는 경우인 것으로 판단.

# %%
### 결측치의 비율 출력해보기

percent_missing = df_o.isnull().sum() * 100 / len(df_o)

percent_missing
# Out:
# id                         0.000000
# customer_id                0.002846
# course_id                  4.939337
# type                       0.000000
# state                      0.000000
# course_title               0.015178
# category_title             0.022766
# format                     0.015178
# completed_at               0.000000
# transaction_amount         0.000000
# coupon_title              69.818534
# coupon_discount_amount    69.818534
# sale_price                 1.070016
# tax_free_amount            1.070016
# pg                        14.300079
# method                    12.422808
# subcategory_title         18.809702
# marketing_start_at        17.054800
# dtype: float64

# %% [markdown]
# #### ∴ 위 데이터로부터 유추할 수 있는 사실 [+처리여부]
# 1. customer_id의 결측이 0.002%, 의미없는 데이터가 아닐까? [삭제완료]
# 2. <b>course_id</b> 의 결측이 약 5% 하지만, course_title의 결측이 0.015%이니,
# - 데이터 안에서 조건문을 돌리게 되면 match가 되게 채울 수 있지 않을까 ? [살펴보니, promotion 등의 자료였음]
# 3. course_title, category_title, format 의 경우 결측이 0.01~2% 수준으로, 상당이 낮음.
# - 한번 살펴보고 가자. [category_title, format 못봤음]
# 4. 2021.03.29~2021.09.26 패스트캠퍼스 온라인 강의 결제 내역 결제 건에서 쿠폰이 사용된 건은 약 30%.
# - (결측치가 69%이니까) 이를 통해 쿠폰은 고객의 결제를 유도하는 효과가 있다는 것이 자명함.
#   [기간 별 판매실적에서 다룰 수 있을 것이며, 결측치 처리하면 안될 것으로 판단]
# 5. pg의 결측치가 14.3%인데, 결제 플랫폼이 사용되지 않았으니 이들은 무통장입금(계좌이체)의 방법을 사용하지 않았을까? [더이상 develop 시킬 만한 추가자료가 없음]
# 6. sale_price / tax_free_amount의 경우 결측이 1.07% 수준인데, 왜일까 ?
# - 한번 그룹화해서 출력해 보자. 의미있는 얘기가 나올 수 있지 않을까.
# [유의 : 결측과 0을 구분하기 ]
# 7. course_title 로 subcategory_title columnm을 혹시 채울 수 있지 않을까?
# [미완료]
# 8. method 결측치가 12.42%인데 왜 일까?
# [미완료]
# 9. marketing_start_at 은 잘 모르겠다...
# [미완료]

# %% [markdown]
# ### customer_id

# %%
df_o[df_o['customer_id'].isnull()]
# Out:
#             id  customer_id  course_id         type      state course_title  \
# 12133  1011200          NaN        NaN  TRANSACTION  COMPLETED          NaN
# 36367  1066932          NaN        NaN  TRANSACTION  COMPLETED          NaN
# 91500  1299115          NaN        NaN  TRANSACTION  COMPLETED          NaN
#
#       category_title format        completed_at  transaction_amount  \
# 12133            NaN    NaN 2021-04-12 11:40:00                   0
# 36367            NaN    NaN 2021-05-17 16:12:00                   0
# 91500            NaN    NaN 2021-08-20 20:05:00                   0
#
#       coupon_title  coupon_discount_amount  sale_price  tax_free_amount   pg  \
# 12133          NaN                     NaN         NaN              NaN  NaN
# 36367          NaN                     NaN         NaN              NaN  NaN
# 91500          NaN                     NaN         NaN              NaN  NaN
#
#              method subcategory_title marketing_start_at
# ...

# %%
'''
1. customer_id 결측의 3개임을 확인하였고 살펴 본 결과, 
Method가 B2B_CONTRACT인 것 외 아무 정보도 확인할 수 없음.
따라서 삭제하는 것이 맞다고 판단함.
'''
df_o.dropna(subset='customer_id', inplace=True)

# %% [markdown]
# ### course_id, course_title

# %%
df_o.course_id.nunique()
# 1347개의 서로 다른 종류의 강좌가 개설되어있는걸까 ?
# Out:
# 1347

# %%
df_o.course_id.value_counts().head(421)
# 코스아이디로 보면, 1347개의 서로 다른 종류의 강의가 판매되었다고 판단...해야하지만 자세히 보자
# 소결 : 420 종의 강의는 2번 이상 결제가 되었다고 봐도 될까? 그외 1347-420 개의 강의는 1번 씩 판매가 되었어.
# Out:
# 203720.0    3257
# 203525.0    2756
# 203178.0    2541
# 204670.0    2132
# 204871.0    1636
#             ...
# 204149.0       2
# 205049.0       2
# 205995.0       2
# 204014.0       2
# 204523.0       1
# Name: course_id, Length: 421, dtype: int64

# %%
df_o.loc[df_o.course_id == 203178.0].head(50)
# course_id 존재할 때, course_title을 대표하는 값으로 봐도 되겠네. [동일]
# Out:
#           id  customer_id  course_id     type      state  \
# 1     970650     432862.0   203178.0    ORDER  CANCELLED
# 8     970669     478033.0   203178.0  PAYMENT  COMPLETED
# 9     970667     478033.0   203178.0    ORDER  CANCELLED
# 26    970697     478048.0   203178.0    ORDER  CANCELLED
# 129   971036     478207.0   203178.0    ORDER  CANCELLED
# 144   971082     478170.0   203178.0    ORDER  CANCELLED
# 150   971105     478233.0   203178.0  PAYMENT  COMPLETED
# 157   971143     478246.0   203178.0  PAYMENT  COMPLETED
# 158   971130     478246.0   203178.0    ORDER  CANCELLED
# 279   971455     183570.0   203178.0  PAYMENT  COMPLETED
# 445   971824     478261.0   203178.0    ORDER  CANCELLED
# 485   971933     477747.0   203178.0    ORDER  CANCELLED
# 497   971972     478466.0   203178.0    ORDER  CANCELLED
# 504   971993     478540.0   203178.0    ORDER  CANCELLED
# 599   972256      33381.0   203178.0  PAYMENT  COMPLETED
# ...

# %%
'''
2. course_id 와 course_title의 관계성을 파악해보고, 채울 수 있을지에 대한 판단 진행.
'''
print(df_o['course_id'].isnull().sum())
df_course_id_isnull = df_o[df_o['course_id'].isnull()]
# 의견 : df_course_id_isnull은 course_id가 결측된 것들로,
# 살펴보니 프로모션 / 한정판매 등의 타이틀이 있는 데이터들이네 ?, 채우지 않고 따로 다뤄야 할 것 같다.
# Out:
# 5204

# %%
df_course_id_isnull.head(100)
df_course_id_isnull.course_title.value_counts().head(50)
# [프로모션] 붙어있는 것 및 데이터 유효성 확인
# Out:
# 프로모션 : 내 커리어 지켜 줄 UX/UI 디자인 무제한 패스 (4월 프리패스)            124
# 프로모션 : 2+2 나의 디자인 DNA찾기! 디자이너를 위한 PASS (6월 프리패스)        118
# 프로모션 : 기초부터 시작하는 데이터분석 무제한 패스 (4월 프리패스)                 115
# 프로모션 : 영상 퀄리티를 바꿔 줄 영상 제작 스킬 무제한 패스 (4월 프리패스)            97
# 프로모션 : 코딩 LEVEL UP 웹 개발 풀스텍 무제한 패스 (4월 프리패스)             94
# 프로모션 : 2+2 한 번에 끝내는 개발 풀스택 쌓기 PASS (6월 프리패스)             89
# 프로모션 : 커리어를 UP UX/UI 디자인 무제한 99패스 (5월 프리패스)              83
# 프로모션 : 주니어 프론트엔드 개발자를 위한 무제한 99패스 (5월 프리패스)              80
# 프로모션 : 2+2 연봉 앞자리가 바뀌는 앱개발 PASS (6월 프리패스)                77
# 프로모션 : 한 번에 끝내는 개발 풀스택 쌓기 BEST PASS (7월 프리패스)            77
# 프로모션 : 2+2 커리어를 UP! UX/UI 디자인 PASS (6월 프리패스)             76
# 프로모션 : 2+2 코딩실력 LEVEL UP 웹 개발 PASS (6월 프리패스)             66
# 프로모션 : 2+2 기초부터 다지는 데이터분석 PASS  (6월 프리패스)                62
# 프로모션 : 2+2 영상 퀄리티를 높이는 전문가 편집스킬 PASS (6월 프리패스)           61
# 프로모션 : 연봉 앞자리가 바뀌는 앱개발 무제한 패스 (4월 프리패스)                  61
# 프로모션 : 2+2 풀스택 마케터를 위한 마케팅 PASS  (6월 프리패스)               60
# ...

# %%
# course_id가 결측치가 있는 course_title을 한번 자세히 보자 
print(df_course_id_isnull.course_title.nunique())
df_course_id_isnull.course_title.unique()

# course_id 결측치 : 5204 - 그 중 309종 서로 다른 건의 '대부분 프로모션'이라는 타이틀을 달고, 있는 항목들!
# 구매 패턴 분석 시, 프로모션 샘플링해서 분석비교 어떨까.
# 수치 count 및 transaction_amount 곱해서 얼마 벌었는지 table 및 가시화 가능 할 거같은데.
# 제대로 뽑으려면 group_by 도 해 줘야겠네..
# Out:
# 309
# array(['프로모션 : 2021 내 커리어 지켜 줄 UX/UI 디자인 한끝세트 (3월 프리패스)',
#        '프로모션 : 코딩 LEVEL UP 웹 개발 풀스텍 한끝세트 (3월 프리패스)',
#        '프로모션 : 기초부터 시작하는 데이터분석 한끝세트 (3월 프리패스)',
#        '[한정판매] 자연어 A-Z 끝장 패키지(~3월)',
#        '프로모션 :연봉 앞자리가 바뀌는 프론트엔드 한끝세트 (3월 프리패스)',
#        '프로모션 : 매출의 판도를 바꾸는 마케팅 한끝세트 (3월 프리패스)',
#        '프로모션 :개발자를 위한 코딩 백과사전 한끝세트 (3월 프리패스)',
#        '프로모션 : 데이터 활용 능력을 바꿔 줄 데이터 분석 한끝세트 (3월 프리패스)',
#        '프로모션 : 시장의 흐름을 읽는 투자의 정석 한끝세트 (3월 프리패스)',
#        '프로모션 : 사수없이 고민말고! 필요할 때 꺼내보는 마케팅 백과사전 한끝세트 (3월 프리패스)',
#        '프로모션 : 2021 내 연봉을 바꿔 줄 직장인 스킬업 한끝세트 (3월 프리패스)',
#        '프로모션 : 투자의 방향성을 세우는 기업분석 한끝세트 (3월 프리패스)',
#        '프로모션 : 딥러닝 기초부터 인사이트까지 언제든 꺼내볼 나만의 딥러닝 백과사전 한끝세트 (3월 프리패스)',
#        '프로모션 : 영상 퀄리티를 바꿔 줄 영상 제작 스킬 한끝세트 (3월 프리패스)',
#        '프로모션 : 데이터 보는 눈을 바꿔 줄 데이터 마케팅 한끝세트 (3월 프리패스)',
#        '[한정판매] 자연어처리 끝장 패키지(~3월)',
#        '프로모션 : 사무실에서 꺼내보는 직장인 필수 한끝세트 (3월 프리패스)',
#        '프로모션 : Top tier 프로젝트를 만드는 한끝세트 (3월 프리패스)',
# ...

# %%
'''
       '초격차 패키지: 30개 프로젝트로 배우는 Android 앱 개발 with Kotlin 특별할인',
       '초격차 패키지 : 한 번에 끝내는 PPT 제작/디자인',
       '올인원 패키지 : SNS 콘텐츠 기획/제작 MAX 2020 + [20%할인쿠폰]초격차 패키지 : 무조건 팔리는 SNS 콘텐츠 끝장내기',

이 3개의 타이틀이 outlier 일까 ?
'''
# Out:
# "\n       '초격차 패키지: 30개 프로젝트로 배우는 Android 앱 개발 with Kotlin 특별할인',\n       '초격차 패키지 : 한 번에 끝내는 PPT 제작/디자인',\n       '올인원 패키지 : SNS 콘텐츠 기획/제작 MAX 2020 + [20%할인쿠폰]초격차 패키지 : 무조건 팔리는 SNS 콘텐츠 끝장내기',\n\n이 3개의 타이틀이 outlier 일까 ?\n"

# %%
df_o.loc[df_o.course_title == '초격차 패키지: 30개 프로젝트로 배우는 Android 앱 개발 with Kotlin 특별할인',] # 1 row
df_o.loc[df_o.course_title == '초격차 패키지 : 한 번에 끝내는 PPT 제작/디자인'] # 2 rows
# Out:
#             id  customer_id  course_id     type      state  \
# 73342  1216658     486850.0        NaN  PAYMENT  COMPLETED
# 73343  1216659     588382.0        NaN  PAYMENT  COMPLETED
#
#                         course_title category_title format  \
# 73342  초격차 패키지 : 한 번에 끝내는 PPT 제작/디자인         업무 생산성    올인원
# 73343  초격차 패키지 : 한 번에 끝내는 PPT 제작/디자인         업무 생산성    올인원
#
#              completed_at  transaction_amount coupon_title  \
# 73342 2021-07-14 14:43:03              103000          NaN
# 73343 2021-07-14 14:43:03              103000          NaN
#
#        coupon_discount_amount  sale_price  tax_free_amount   pg    method  \
# 73342                     NaN    103000.0         103000.0  NaN  TRANSFER
# 73343                     NaN    103000.0         103000.0  NaN  TRANSFER
#
#       subcategory_title marketing_start_at
# 73342               NaN                NaT
# 73343               NaN                NaT

# %%
df_o.loc[df_o.course_title == '올인원 패키지 : SNS 콘텐츠 기획/제작 MAX 2020 + [20%할인쿠폰]초격차 패키지 : 무조건 팔리는 SNS 콘텐츠 끝장내기'] #1 row
# Out:
#             id  customer_id  course_id     type      state  \
# 81802  1253011     613302.0        NaN  PAYMENT  COMPLETED
#
#                                             course_title category_title  \
# 81802  올인원 패키지 : SNS 콘텐츠 기획/제작 MAX 2020 + [20%할인쿠폰]초격...            마케팅
#
#       format        completed_at  transaction_amount coupon_title  \
# 81802    올인원 2021-07-30 15:27:16              138000          NaN
#
#        coupon_discount_amount  sale_price  tax_free_amount   pg    method  \
# 81802                     NaN    138000.0         138000.0  NaN  TRANSFER
#
#       subcategory_title marketing_start_at
# 81802            SNS마케팅                NaT

# %%
df_o[df_o.course_title.isna()]
#식별할 수 있는 정보가 없다고 판단하여, 삭제
df_o.dropna(subset='course_title', inplace=True)

# %%
## 초격자패키지로 시작하는 course title 출력 - 약간의 mismatch 있지만 약 3만여개
df_o.loc[df_o.course_title.str.startswith("초격차 패키지")] # 30644 rows
df_o.loc[df_o.course_title.str.contains("초격차 패키지")] # 31244 rows

# %%
## 올인원 패키지로 시작하는 course title 출력 - 약간의 mismatch 있지만 약 4만 4천여개
df_o.loc[df_o.course_title.str.startswith("올인원 패키지")] # 44053 rows
df_o.loc[df_o.course_title.str.contains("올인원 패키지")] # 44273 rows
# Out:
#              id  customer_id  course_id     type      state  \
# 0        970634     504760.0   201435.0    ORDER  CANCELLED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 5        970655     478028.0   201797.0    ORDER  CANCELLED
# 7        970664     460730.0   200622.0    ORDER  CANCELLED
# 10       970671     469860.0   203644.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105398  1364886     578540.0   202789.0  PAYMENT  COMPLETED
# 105402  1364916     670833.0   201582.0  PAYMENT  CANCELLED
# 105403  1364919     670833.0   201582.0  PAYMENT  COMPLETED
# 105404  1364920     670837.0   201582.0  PAYMENT  CANCELLED
# 105409  1364960     670874.0   204342.0  PAYMENT  CANCELLED
#
#                                           course_title category_title format  \
# 0                            올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍    올인원
# 4                        올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성    올인원
# ...

# %%
df_o.loc[df_o.course_title.str.contains("올인원 패키지|초격차 패키지")] # 75516개 (합연산 해봤음)
# Out:
#              id  customer_id  course_id     type      state  \
# 0        970634     504760.0   201435.0    ORDER  CANCELLED
# 1        970650     432862.0   203178.0    ORDER  CANCELLED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 5        970655     478028.0   201797.0    ORDER  CANCELLED
# 7        970664     460730.0   200622.0    ORDER  CANCELLED
# ...         ...          ...        ...      ...        ...
# 105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
# 105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
#
#                            course_title category_title format  \
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍    올인원
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# ...

# %%
df_o.loc[df_o.course_title.str.contains("패키지")] # 77615개
# 결론 : 판매 된 10만여개의 강의 중 77600여개의 강의가 패키지 강의임을 확인
# Out:
#              id  customer_id  course_id     type      state  \
# 0        970634     504760.0   201435.0    ORDER  CANCELLED
# 1        970650     432862.0   203178.0    ORDER  CANCELLED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 5        970655     478028.0   201797.0    ORDER  CANCELLED
# 7        970664     460730.0   200622.0    ORDER  CANCELLED
# ...         ...          ...        ...      ...        ...
# 105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
# 105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
#
#                            course_title category_title format  \
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍    올인원
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# ...

# %%
df_o.loc[~df_o.course_title.str.contains("패키지")]
# 그렇다고 해서, 나머지 course_title 확인 해 보니, 단일강좌로만 이루어져있다고 판단할 수 없었다.
# Out:
#              id  customer_id  course_id     type      state  \
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3        970656      72297.0   204246.0    ORDER  CANCELLED
# 6        970614     477910.0        NaN    ORDER  CANCELLED
# 12       970670     429291.0        NaN    ORDER  CANCELLED
# 13       970672     429291.0        NaN    ORDER  CANCELLED
# ...         ...          ...        ...      ...        ...
# 105408  1364956     545804.0        NaN  PAYMENT  COMPLETED
# 105410  1364965     144883.0        NaN  PAYMENT  CANCELLED
# 105415  1364998     670896.0   204159.0  PAYMENT  CANCELLED
# 105417  1365005     670896.0   204159.0  PAYMENT  CANCELLED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                            course_title category_title  \
# 2                                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍
# 3                                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍
# ...

# %%
df_o.loc[df_o.course_title.str.contains("시크릿")] # 292 rows
# Out:
#             id  customer_id  course_id     type      state  \
# 2       970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3       970656      72297.0   204246.0    ORDER  CANCELLED
# 193     971243     478288.0   204246.0    ORDER  CANCELLED
# 203     971265     175430.0   204246.0  PAYMENT  COMPLETED
# 204     971261     175430.0   204246.0    ORDER  CANCELLED
# ...        ...          ...        ...      ...        ...
# 58541  1156069     154959.0   204246.0  PAYMENT  COMPLETED
# 58542  1156068     154959.0   204246.0    ORDER  CANCELLED
# 70604  1204194     133772.0   203986.0    ORDER  CANCELLED
# 71111  1206857     429700.0   203986.0   REFUND  COMPLETED
# 73891  1218798     490371.0   204246.0   REFUND  COMPLETED
#
#                   course_title category_title  format        completed_at  \
# 2         시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# 3         시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
# ...

# %%
## 프로모션 시작하는 course title
df_o.loc[df_o.course_title.str.match("프로모션")] # 4932 rows
df_o.loc[df_o.course_title.str.startswith("프로모션")] # 4932 rows
df_o.loc[df_o.course_title.str.contains("프로모션")] # 5551 rows
# Out:
#              id  customer_id  course_id     type      state  \
# 6        970614     477910.0        NaN    ORDER  CANCELLED
# 12       970670     429291.0        NaN    ORDER  CANCELLED
# 13       970672     429291.0        NaN    ORDER  CANCELLED
# 16       970677     429291.0        NaN    ORDER  CANCELLED
# 18       970682     478031.0        NaN  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105272  1364334     436116.0        NaN  PAYMENT  COMPLETED
# 105307  1364532     653384.0        NaN  PAYMENT  CANCELLED
# 105311  1364534     653384.0        NaN  PAYMENT  CANCELLED
# 105408  1364956     545804.0        NaN  PAYMENT  COMPLETED
# 105410  1364965     144883.0        NaN  PAYMENT  CANCELLED
#
#                                            course_title category_title format  \
# 6       프로모션 : 2021 내 커리어 지켜 줄 UX/UI 디자인 한끝세트 (3월 프리패스)         크리에이티브    올인원
# 12           프로모션 : 코딩 LEVEL UP 웹 개발 풀스텍 한끝세트 (3월 프리패스)          프로그래밍    올인원
# ...

# %% [markdown]
# 소결 : course_id 로 필터링 해서 분석하니, course_title과의 관련성을 확인하였고, 자료가 string형에 고유값이 많아서 분류하기에 손이 많이 갈 것 같다..

# %% [markdown]
# ### State

# %%
df_o.state.nunique()
df_o.state.value_counts()
# Out:
# COMPLETED    62759
# CANCELLED    41279
# PENDING       1144
# DELETED        207
# REQUESTED       14
# Name: state, dtype: int64

# %%
'''
Q4. state 컬럼에서 DELETED, PENDING, REQUESTED는 무슨 뜻인가요?
A4. REQUESTED는 고객에게 결제 요청을 보낸 상태입니다. 나머지는 무시하셔도 좋습니다.
'''
# 14 개의 REQUESTED 가 어떻게 생긴지 궁금하다.
cond = df_o.state == 'REQUESTED'
# 결제 요청했으나, 사용자 사정? 에 의해 완료되지 못한 건에 대한 액수 산정 간단히 해보자.
temp_df = df_o.loc[cond][["state","course_title","transaction_amount"]].reset_index(drop=True)
display(temp_df)
print("Sum of REQUESTED rows : %d" % temp_df['transaction_amount'].sum())
# Out:
#         state                                 course_title  transaction_amount
# 0   REQUESTED                           매주)디지털 마케팅 온라인 완주반              471200
# 1   REQUESTED                올인원 패키지 : 바다가 알려주는 감성가득 영상 제작               90000
# 2   REQUESTED         올인원 패키지 : 다빈치리졸브로 배우는 영상 색 보정 A to Z               90500
# 3   REQUESTED                     초격차 패키지 : 한 번에 끝내는 엑셀 실무               97000
# 4   REQUESTED                    데이터분석 프로젝트+자격증 온라인 완주반 4기              320000
# 5   REQUESTED                       올인원 패키지 : 코딩 첫 걸음 프로젝트               87500
# 6   REQUESTED        올인원 패키지 : 누적 조회수 12억! 우감독의 재미있는 영상 편집               89000
# 7   REQUESTED  프로모션 : 나의 디자인 DNA찾기! 디자인 무제한 99패스 (5월 프리패스)              199000
# 8   REQUESTED       초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터               93500
# 9   REQUESTED              올인원 패키지 : 프로젝트와 함께 배우는 R 데이터 분석              136000
# 10  REQUESTED           초격차 패키지 : 한 번에 끝내는 node.js 웹 프로그래밍               79000
# ...

# %%
# 용담강사님의 comment에 따라 state = DELETED, PENDING, REQUESTED[데이터 확인 완료] 에 대한 일괄 삭제 진행
cond = (df_o.state == 'DELETED')|(df_o.state == 'PENDING')|(df_o.state == 'REQUESTED') 
#df_o[cond]
## 위 masking condition으로 출력 시 1365 rows 확인
# 위 결과를 제거 (결과에 반영)
df_o = df_o.drop(df_o[cond].index)
df_o
df_o.type.unique()
# state = DELETED, PENDING, REQUESTED에 대한 일괄 삭제 완료
# Out:
# array(['ORDER', 'PAYMENT', 'REFUND'], dtype=object)

# %%
df_o.describe()
# Out:
#                  id    customer_id      course_id  transaction_amount  \
# count  1.040380e+05  104038.000000   98937.000000        1.040380e+05
# mean   1.147326e+06  417124.444799  203868.691784        1.460368e+05
# std    1.124861e+05  206599.489439    1537.499849        7.231787e+05
# min    5.679930e+05      16.000000    2516.000000       -4.144074e+06
# 25%    1.049341e+06  239847.250000  203078.000000        8.300000e+04
# 50%    1.136046e+06  501200.500000  203787.000000        1.170000e+05
# 75%    1.240586e+06  566710.000000  204775.000000        1.584000e+05
# max    1.381657e+06  672308.000000  207742.000000        1.134000e+08
#
#        coupon_discount_amount    sale_price  tax_free_amount
# count            3.135000e+04  1.029590e+05     1.029590e+05
# mean             5.009274e+04  1.610193e+05     1.575282e+05
# std              5.650925e+04  3.977652e+05     3.921484e+05
# min              0.000000e+00  1.000000e+00     0.000000e+00
# ...

# %%
'''
기업의 성장을 위해서 고려해야할 요소가 매출/순이익 이라는 것은 자명하다. 첫째로 살펴볼 것은 역시나 transaction_amount일 것이다.
기업이 유지되기 위해서는, 통상적으로 아래의 기준에 맞추어서 데이터를 바라보아야 한다.

1. 다양한 마케팅/홍보활동을 통한 신규 사용자들의 유입 -> 구매 패턴 분석을 통한 소요확인

2. 기존 유저들의 이탈율 감소/지속적인 구매유도를 위한 전략 수립 -> 고객군 분석을 통한 보편적인 성향 확인
'''
# Out:
# '\n기업의 성장을 위해서 고려해야할 요소가 매출/순이익 이라는 것은 자명하다. 첫째로 살펴볼 것은 역시나 transaction_amount일 것이다.\n기업이 유지되기 위해서는, 통상적으로 아래의 기준에 맞추어서 데이터를 바라보아야 한다.\n\n1. 다양한 마케팅/홍보활동을 통한 신규 사용자들의 유입 -> 구매 패턴 분석을 통한 소요확인\n\n2. 기존 유저들의 이탈율 감소/지속적인 구매유도를 위한 전략 수립 -> 고객군 분석을 통한 보편적인 성향 확인\n'

# %%
## 얼마짜리가 가장 비쌀까 ? 
print(f"Maximum Transaction Amount : {df_o['transaction_amount'].max()}, {df_o['transaction_amount'].argmax()}")
df_o.iloc[22242]

# 단건결제에서 113,400,000원 [일억일천만삼천사백만원] 결제한 것으로, B2B 건이다!
# Out:
# Maximum Transaction Amount : 113400000, 22242
# id                                                    1039468
# customer_id                                          512983.0
# course_id                                            204638.0
# type                                                  PAYMENT
# state                                               COMPLETED
# course_title              (B2B) 서울형 청년인턴 디지털 마케팅 및 영업 과정 (국내)
# category_title                                            마케팅
# format                                                    B2B
# completed_at                              2021-04-29 15:51:40
# transaction_amount                                  113400000
# coupon_title                                              NaN
# coupon_discount_amount                                    NaN
# sale_price                                                NaN
# tax_free_amount                                           NaN
# ...

# %%
# 혹시, 이 B2B 거래건의 고객이 다른 구입도 하지 않았을까 ?
#df_o.loc[df_o.customer_id == 512983] # 확인해보니 단일 건외 추가결제 내역이 존재하지 않는다. 더 큰 손(고객)이 있을지도 모른다.

# %% [markdown]
# - 전처리 특기사항 : type column에서 ORDER의 경우 삭제하는게, 이익(PAYMENT) 측면에서 봐야하니(강사님의 서술)

# %%
# df_o[df_o.type.isna()] 
df_o.type.unique()
# 추후에 살려야할 수도 있으니, 카피본으로 'type' == ORDER 날리자.
df_i = df_o.copy()
df_i.drop(df_i[df_i.type == 'ORDER'].index, inplace=True)
df_i # 날리고 나니까, 63879 rows left
df_i.type.unique()
# Out:
# array(['PAYMENT', 'REFUND'], dtype=object)

# %% [markdown]
# # Explolatory Data Analysis(EDA)

# %%
# 컬럼 별 데이터타입 확인
df_i.dtypes
# Out:
# id                                 int64
# customer_id                      float64
# course_id                        float64
# type                              object
# state                             object
# course_title                      object
# category_title                    object
# format                            object
# completed_at              datetime64[ns]
# transaction_amount                 int64
# coupon_title                      object
# coupon_discount_amount           float64
# sale_price                       float64
# tax_free_amount                  float64
# pg                                object
# method                            object
# subcategory_title                 object
# marketing_start_at        datetime64[ns]
# dtype: object

# %% [markdown]
# ### 데이터타입 요약
#   * 수치형 : id, customer_id, course_id, transaction_amount, coupon_title, coupon_discount-amount, sale_price, tax_free_amount
#   * 범주형/정보포함 : type, state, course_title, category_title, format, coupon_title,
#   * 날짜/시간형 : completed_at, marketing_start_at

# %% [markdown]
# ### 변수 요약
#   df_o : 전처리 완료 된 원본데이터
#   df_i : 세부 EDA를 위한 전처리된 data
#   cond : 각 문의 filter를 위한 mask
#   percent_missing : 결측치 퍼센트 계산 결과
#   temp_df : state == 'REQUESTED' 임시로 확인하기 위해 생성

# %%
# 총 데이터의 구조 확인 [63879 * 18]
df_i.abs
# Out:
# <bound method NDFrame.abs of              id  customer_id  course_id     type      state  \
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8        970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10       970671     469860.0   203644.0  PAYMENT  COMPLETED
# 14       970676     478035.0   203720.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105415  1364998     670896.0   204159.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105417  1365005     670896.0   204159.0  PAYMENT  CANCELLED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                           course_title category_title  format  \
# 2                                 시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# ...

# %%
## 컬럼명 실수 방지를 위한 버퍼
df_o.columns
# Out:
# Index(['id', 'customer_id', 'course_id', 'type', 'state', 'course_title',
#        'category_title', 'format', 'completed_at', 'transaction_amount',
#        'coupon_title', 'coupon_discount_amount', 'sale_price',
#        'tax_free_amount', 'pg', 'method', 'subcategory_title',
#        'marketing_start_at'],
#       dtype='object')

# %% [markdown]
#     - 결측치 : 단순 누락/유실일 지, 공통적으로 없는지 점검해보기
#         - 복잡하게 생각하지 말기!

# %%
#df_i.loc[df_i.id.isna()] # id에 결측치 제거 완료

# %% [markdown]
# ## overall EDA 진행(이정훈님 part)

# %% [markdown]
#     - 아래 3.에서의 column 값 뽑기전에, data format과 결측치 '재확인' 하고 진행하기.

# %% [markdown]
# 3. 미래의 방향성을 제시하려면, 현재의 데이터를 잘 알아야한다. - 현재 이익(기준 : transaction_amount) 이 나게 된 원인을 분석하자.

# %% [markdown]
#     - sale_price(과정에 대한 고정가격), transaction_amount(마케팅, 할인가격 등이 반영된)를 일단 살펴본다.

# %%
# COMPLETED / CANCELLED 실적 확인
display(df_i.state.value_counts())

# state [ completed / cancelled ] 에 대해, transaction_amount 비교 / 시각화  
#display(df_i[['state', 'transaction_amount']])
x1 = df_i[['state', 'transaction_amount']]
display(x1.groupby('state').agg(['count','sum']))
# Out:
# COMPLETED    56723
# CANCELLED     7156
# Name: state, dtype: int64
#           transaction_amount
#                        count         sum
# state
# CANCELLED               7156  1416919450
# COMPLETED              56723  8002033457

# %%
 # 결제금액의 합계 : 8002033457 --> 7원 ? 발견. 잘못된걸까?
x1[x1.transaction_amount % 10 != 0] # 375개의 row가 원단위..가 살아있는 것을 확인하였다. 

# 추가적으로 -값에 해당하는 자료도 확인. 어쨋든 연산이 안되는 것은 아니니, 전처리해야될 부분은 아닌 것 같고.
# 왜 그런지 분석을 더 할 수 있을까 ?
# Out:
#             state  transaction_amount
# 126     COMPLETED              119225
# 389     COMPLETED              182875
# 1160    COMPLETED              -89333
# 1265    COMPLETED              -59333
# 1450    COMPLETED              -76333
# ...           ...                 ...
# 102829  COMPLETED             -161141
# 103351  COMPLETED             -133077
# 104734  COMPLETED              -63333
# 104900  COMPLETED             -111925
# 105248  COMPLETED             -108186
#
# [375 rows x 2 columns]

# %%
pt = x1.groupby('state').agg(sum).reset_index()


# ∴ 통상 외화결제가 아닌 이상 원단위로 끝나는 경우가 없을 건데.. 할인쿠폰 떄문이 아닐까 싶다.

# Visualization
plt.figure(figsize= (8,6))
plt.title("Comparision between completed and cancelled state", fontsize = 18)
plt.xlabel("Payment State", fontsize = 12)
plt.ylabel("Sum of transaction amount", fontsize = 12)

sns.barplot(x = pt.state, y = pt.transaction_amount)

plt.show()

# %% [markdown]
#     - group_by를 통해 category_title로 묶어서 다시 위 경향에 대해 살펴보자.

# %%
# 한글 폰트 설치
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')

font_list[:]
# Out:
# /var/folders/7w/c5f22hyn2v370ztkkssfpjmr0000gn/T/ipykernel_10621/1004497658.py:3: MatplotlibDeprecationWarning:
# The get_fontconfig_fonts function was deprecated in Matplotlib 3.5 and will be removed two minor releases later.
#   fm.get_fontconfig_fonts()
# ['/System/Library/Fonts/NewYork.ttf',
#  '/System/Library/Fonts/KohinoorGujarati.ttc',
#  '/System/Library/Fonts/Supplemental/Savoye LET.ttc',
#  '/System/Library/Fonts/Supplemental/DIN Condensed Bold.ttf',
#  '/System/Library/Fonts/Supplemental/Andale Mono.ttf',
#  '/System/Library/Fonts/Supplemental/STIXIntUpReg.otf',
#  '/System/Library/Fonts/Avenir Next.ttc',
#  '/System/Library/Fonts/Supplemental/Malayalam MN.ttc',
#  '/System/Library/Fonts/Supplemental/NotoSansTagbanwa-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/STIXIntUpDReg.otf',
#  '/System/Library/Fonts/Supplemental/NotoSansGlagolitic-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/Songti.ttc',
# ...

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
# x1 에 category_title붙여서 groupby 진행
#x1.insert(0,'category_title',df_i['category_title'])
x1 = df_i[['state', 'transaction_amount', 'category_title']]
pt = x1.groupby('category_title').agg(sum).reset_index()
pt.rename(columns={'transaction_amount':'Total_transaction_amount'}, inplace = True)
pt
# Out:
#    category_title  Total_transaction_amount
# 0              관리                    150000
# 1              교육                1213504545
# 2         데이터사이언스                1740977049
# 3             디자인                 835356868
# 4             마케팅                 817135024
# 5          부동산/금융                 564273934
# 6            비즈니스                  10787865
# 7          업무 생산성                 681045525
# 8           영상/3D                 676128705
# 9           지식콘텐츠                   4970000
# 10         크리에이티브                 434005827
# 11         투자/재테크                 369477520
# 12           파이낸스                   7080000
# 13          프로그래밍                2056879045

# %%
# 데이터 사이언스 / 데이터사이언스 가 사실 상 같은 자료이다. 수정하자.
#df_i[df_i.category_title == '데이터 사이언스'] # 6 rows to modify
#df_i.category_title.replace('데이터 사이언스', '데이터사이언스', inplace=True) # modification finished

# %%
# Visualization
plt.figure(figsize= (8,6))
plt.title("Comparision between completed and cancelled state", fontsize = 18)
plt.xlabel("Payment State", fontsize = 12)
plt.ylabel("Sum of transaction amount", fontsize = 12)

sns.barplot(y = pt.category_title, x = pt.Total_transaction_amount, order=pt.sort_values('Total_transaction_amount').category_title)
plt.show()
# Out:
# /Users/Kimdaseul/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/Kimdaseul/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/Kimdaseul/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/Kimdaseul/miniforge3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
#     - method 별로 group_by 해서 count, transaction_amount 출력해보자.

# %% [markdown]
#     - pg의 결측치/유효데이터를 확인하고, count 해보자

# %% [markdown]
#         - (편중되는 쪽이 있다면, 이용자가 많다고 간주해도 되니, 마케팅 정책을 수립할 수 있을 것이다.)

# %% [markdown]
#     - 필터 두번해야될 component 있는지 확인 (예시 : 프로그래밍 - 개발자커리어와 프론트엔드 등 다수 존재) 후 count, transaction_amount진행

# %% [markdown]
#     - group_by로 format로 묶어서 transacion_amount 뽑아보자(이때 count는 중요하지 않을 것)

# %% [markdown]
#     - group_by로 course_id 또한 동일하게 진행해 보기
#         * 소결 1회 진행

# %% [markdown]
# ## 기간 별 판매실적 분석 (서정민님 part)

# %% [markdown]
#     - 기간별 판매실적(completed_at) 데이터를 출력해보자. (3,4,5,6,7,8월 등 샘플링 한 것이니까. 경향성이 나올 것이다.)
#         * 정새롬님 의견 : state가 payment일때 completed라는 값을 가지고 있으면 구매일자일 것임.

# %% [markdown]
# ## 구매 패턴 분석 (이민정, 심승우님 part)

# %% [markdown]
#     - 같은 category에서 coupon_title이 존재하는 row를 각각 count 해보자, 기간과 마케팅은 관련성이 있다고 생각하니, 유효한 경향성을 확인할 수 있을 지 모른다.

# %% [markdown]
#         * 소결 2회 진행

# %% [markdown]
# ## 개인 고객군 분석 (정새롬님 part, 완료)

# %%
# df_o = pd.read_excel("./dataanalysisproject_rawdata.xlsx")

# %%
#원본 데이터 변경을 피하기 위해 복사본 사용
df_i = df_o.copy()

# %%
#내부결제로 추정되는 데이터 삭제
dellow = df_i.loc[df_i['id']==47361].index
df_i.drop(dellow, axis='index', inplace=True)

# %%
#기업 고객-B2B교육관련 내용 삭제
B2B = df_i[df_i['format'].str.contains("B2B", na=False, case=False)].index
df_i.drop(B2B,  axis='index', inplace=True)

# %%
#정부사업의 데이터 삭제하기
B2G = df_i[df_i['format'] == "B2G"].index
df_i.drop(B2G,  axis='index', inplace=True)

# %%
#결제가 되지 않은경우 format이 nan 값을 가짐
none = df_i.loc[df_i['format'].isnull()].index
df_i.drop(none, axis='index', inplace=True)

# %%
#환불된 경우 제외
minus = df_i.loc[df_i['transaction_amount'] < 0].index
df_i.drop(minus, axis='index', inplace=True)

# %%
#결제가된 정보를 분석하기 위해
df_ip = df_i[(df_i['type'] == 'PAYMENT') &  (df_i['state'] == 'COMPLETED')]

# %%
df_ip.sort_values('completed_at').tail()
# Out:
#              id  customer_id  course_id     type      state  \
# 105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
# 105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title format  \
# 105411       초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인    올인원
# 105412      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# 105413      초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍    올인원
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D    올인원
# 105418               용호수의 돈 버는 실전 영상 제작          영상/3D    올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 105411 2021-09-25 13:39:26              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105412 2021-09-25 13:46:29              149000                        NaN
# ...

# %%
df_ip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51179 entries, 2 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      51179 non-null  int64
#  1   customer_id             51179 non-null  float64
#  2   course_id               49200 non-null  float64
#  3   type                    51179 non-null  object
#  4   state                   51179 non-null  object
#  5   course_title            51179 non-null  object
#  6   category_title          51177 non-null  object
#  7   format                  51179 non-null  object
#  8   completed_at            51179 non-null  datetime64[ns]
#  9   transaction_amount      51179 non-null  int64
#  10  coupon_title            23723 non-null  object
#  11  coupon_discount_amount  23723 non-null  float64
#  12  sale_price              51077 non-null  float64
#  13  tax_free_amount         51077 non-null  float64
# ...

# %%
df_ip.describe()
# Out:
#                  id    customer_id      course_id  transaction_amount  \
# count  5.117900e+04   51179.000000   49200.000000        5.117900e+04
# mean   1.163893e+06  412282.672913  203900.413069        1.291844e+05
# std    1.172120e+05  214112.119399    1402.561580        1.105564e+05
# min    9.664500e+05      46.000000  200260.000000        0.000000e+00
# 25%    1.059286e+06  174068.500000  203078.000000        8.300000e+04
# 50%    1.156174e+06  500199.000000  203787.000000        1.190000e+05
# 75%    1.273280e+06  574562.500000  204871.000000        1.590000e+05
# max    1.381657e+06  670891.000000  207556.000000        1.800000e+06
#
#        coupon_discount_amount    sale_price  tax_free_amount
# count            2.372300e+04  5.107700e+04     5.107700e+04
# mean             5.459843e+04  1.537650e+05     1.515048e+05
# std              6.005448e+04  1.062397e+05     9.131884e+04
# min              4.950000e+02  1.000000e+00     1.000000e+00
# ...

# %%
#RFM분석: 고객의 최근성(어떤 고객이 최근에 구매한 고객인가), 고객의 구매빈도, 고객의 구매금액을 분석하여
#고객의 타입을 나눠 마케팅 전략을 세우는데 이용됨.
#이를 위해 자료에서 최근 구매일을 기준으로 고객별 최근 구매일을 구하고, 고객의 구매빈도를 구하고 구매금액을 분석해서 어떤 고객군으로 나눌 수 있는지 기준을 세우고자 함.
#나눠진 고객군을 바탕으로 효과적인 마케팅 방안을 찾아보고자 함.

# %%
#Recency
df_user = pd.DataFrame(df_ip['customer_id'])
df_user.columns=['customer_id']
df_max_purchase = df_ip.groupby('customer_id')['completed_at'].max().reset_index() #고객별로 최근 구매한 일자를 구하기 위해 max함수를 이용
df_max_purchase.rename(columns = {'completed_at': 'max_purchase'}, inplace = True)

# %%
df_max_purchase['recency'] = (df_max_purchase['max_purchase'].max() - df_max_purchase['max_purchase']).dt.days
df_user = pd.merge(df_user, df_max_purchase[['customer_id', 'recency']], on='customer_id')

# %%
df_user
# Out:
#        customer_id  recency
# 0          72297.0       42
# 1          72297.0       42
# 2          72297.0       42
# 3          72297.0       42
# 4          72297.0       42
# ...            ...      ...
# 51174     545804.0        0
# 51175     669238.0        0
# 51176     670891.0        0
# 51177     640697.0        0
# 51178     610626.0        0
#
# [51179 rows x 2 columns]

# %%
#중복 데이터를 삭제
df_user = df_user.drop_duplicates(['customer_id'])

# %%
#recency가 0이면 최근 구매일(9월 25일)에 구매를 한 고객이고, recency가 42인 고객은 9월 25일 -42일 전에 결제를 한 고객입니다.

# %%
df_user.recency.describe()
# Out:
# count    38078.000000
# mean        89.983009
# std         52.419365
# min          0.000000
# 25%         43.000000
# 50%         89.000000
# 75%        135.000000
# max        180.000000
# Name: recency, dtype: float64

# %%
plt.figure(figsize=(10, 8))
sns.set(palette='muted', color_codes=True, style='white')
sns.displot(df_user, x='recency', kde=True)
plt.show()

# %%
#가장 최근 구매일(2021-09-25 14:25:47)로부터 개별 고객의 최근 구매일이 평균적으로 83일정도 차이를 보인다는 그래프

# %%
#frequency
df_frequency = df_ip.groupby ('customer_id').completed_at.count().reset_index()
df_frequency.rename(columns={'completed_at':'frequency'}, inplace = True)

df_user = pd.merge(df_user, df_frequency, on='customer_id')
df_user
# Out:
#        customer_id  recency  frequency
# 0          72297.0       42          5
# 1         478028.0      180          1
# 2         478033.0      180          1
# 3         469860.0      180          1
# 4         478035.0      180          1
# ...            ...      ...        ...
# 38073     545804.0        0          1
# 38074     669238.0        0          1
# 38075     670891.0        0          1
# 38076     640697.0        0          1
# 38077     610626.0        0          1
#
# [38078 rows x 3 columns]

# %%
df_user.describe()
# Out:
#          customer_id       recency     frequency
# count   38078.000000  38078.000000  38078.000000
# mean   437738.452650     89.983009      1.344057
# std    203977.016555     52.419365      1.121286
# min        46.000000      0.000000      1.000000
# 25%    287879.750000     43.000000      1.000000
# 50%    516460.500000     89.000000      1.000000
# 75%    586027.750000    135.000000      1.000000
# max    670891.000000    180.000000     53.000000

# %%
df_user.sort_values('frequency').tail(20)
# Out:
#        customer_id  recency  frequency
# 7894      273223.0      148         15
# 2517      270542.0       11         15
# 2114       14845.0       10         16
# 4279       98499.0       19         16
# 270       417924.0        7         18
# 7678         631.0       38         19
# 21198     502821.0       82         19
# 2090       72501.0        5         21
# 832         6526.0        4         22
# 644        20784.0       17         26
# 137        65665.0        2         27
# 10143     106662.0       29         29
# 332       276705.0        7         33
# 5601       40783.0       17         34
# 3260        1189.0        1         37
# 2192       50769.0        2         39
# 846         3189.0        9         39
# 513       158374.0        9         42
# 530       427973.0        1         47
# 2067       98685.0        2         53

# %%
df_ip.loc[df_i['customer_id'] == 98685.0	]
# Out:
#              id  customer_id  course_id     type      state  \
# 5119     984635      98685.0   201998.0  PAYMENT  COMPLETED
# 6337     988664      98685.0   204342.0  PAYMENT  COMPLETED
# 6936     990338      98685.0   201798.0  PAYMENT  COMPLETED
# 22011   1037244      98685.0   200399.0  PAYMENT  COMPLETED
# 22012   1037248      98685.0   201849.0  PAYMENT  COMPLETED
# 22014   1037252      98685.0   204286.0  PAYMENT  COMPLETED
# 23448   1041392      98685.0   204775.0  PAYMENT  COMPLETED
# 28280   1054819      98685.0   204773.0  PAYMENT  COMPLETED
# 33455   1069671      98685.0   204631.0  PAYMENT  COMPLETED
# 50612   1127326      98685.0   201520.0  PAYMENT  COMPLETED
# 50625   1127354      98685.0   202698.0  PAYMENT  COMPLETED
# 56145   1147494      98685.0   205365.0  PAYMENT  COMPLETED
# 57462   1152812      98685.0   205548.0  PAYMENT  COMPLETED
# 60172   1162918      98685.0   205231.0  PAYMENT  COMPLETED
# 60174   1162922      98685.0   205807.0  PAYMENT  COMPLETED
# ...

# %%
#별다른 이상체는 보이지 않으니 삭제하지 않고 분석을 진행하겠습니다.

# %%
plt.figure(figsize=(10, 8))
sns.set(palette='muted', color_codes=True, style='white')
sns.displot(df_user, x='frequency', kind='kde')
plt.show()

# %%
#보통 1번 구매한 고객이 가장 많았고 최다 구매기록은 53회로 집계되었습니다.

# %%
#monetary 결제금액을 뜻하며 쿠폰등을 통해 결제할때 등을 고려해 소비자가 인지하는 구매금액인 transaction amount로 결졍했습니다.
df_monetary = df_ip.groupby('customer_id').transaction_amount.sum().reset_index()
df_monetary.rename(columns={'transaction_amount':'monetary'}, inplace = True)
df_user = pd.merge(df_user, df_monetary, on = 'customer_id')

# %%
df_user.describe()
# Out:
#          customer_id       recency     frequency      monetary
# count   38078.000000  38078.000000  38078.000000  3.807800e+04
# mean   437738.452650     89.983009      1.344057  1.736312e+05
# std    203977.016555     52.419365      1.121286  1.806426e+05
# min        46.000000      0.000000      1.000000  0.000000e+00
# 25%    287879.750000     43.000000      1.000000  9.800000e+04
# 50%    516460.500000     89.000000      1.000000  1.320000e+05
# 75%    586027.750000    135.000000      1.000000  1.980000e+05
# max    670891.000000    180.000000     53.000000  7.040750e+06

# %%
#결제금액이...0원?
df_i.loc[df_i['transaction_amount'] == 0]
# Out:
#              id  customer_id  course_id     type      state  \
# 357      971612      14030.0   203525.0  PAYMENT  COMPLETED
# 508      972001     458172.0   201478.0  PAYMENT  COMPLETED
# 527      972056     464239.0   201435.0  PAYMENT  COMPLETED
# 545      972116     440315.0   201518.0  PAYMENT  COMPLETED
# 547      972122     440315.0   201435.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105179  1363763      23638.0   206742.0  PAYMENT  COMPLETED
# 105197  1363886     377623.0   206257.0  PAYMENT  COMPLETED
# 105261  1364276     455280.0   203529.0  PAYMENT  COMPLETED
# 105273  1364341     475055.0   205579.0  PAYMENT  COMPLETED
# 105306  1364526     665031.0   204373.0  PAYMENT  COMPLETED
#
#                                          course_title category_title format  \
# 357            초격차 패키지 : 한번에 끝내는 Java/Spring 웹 개발 마스터          프로그래밍    올인원
# 508                 올인원 패키지 : TypeScript & Angular 실전          프로그래밍    올인원
# ...

# %%
#무료쿠폰을...넣어야 할까 고민하다 일단 넣었습니다.

# %%
sns.set(palette='muted', color_codes=True,  style='white')
sns.displot(df_user, x='monetary', kde=True)
plt.show()

# %%
df_user.describe()
# Out:
#          customer_id       recency     frequency      monetary
# count   38078.000000  38078.000000  38078.000000  3.807800e+04
# mean   437738.452650     89.983009      1.344057  1.736312e+05
# std    203977.016555     52.419365      1.121286  1.806426e+05
# min        46.000000      0.000000      1.000000  0.000000e+00
# 25%    287879.750000     43.000000      1.000000  9.800000e+04
# 50%    516460.500000     89.000000      1.000000  1.320000e+05
# 75%    586027.750000    135.000000      1.000000  1.980000e+05
# max    670891.000000    180.000000     53.000000  7.040750e+06

# %%
# 각 요소별로 고객에게 점수 매기기 recency는 최근 방문한 고객일 수록 높은 점수를 주었습니다.
def rec(x):
  if x <= 43:
    return 4
  elif x <= 89:
    return 3
  elif x <=135:
    return 2
  else:
    return 1

df_user['recency_score'] = df_user['recency'].map(rec)

# %%
def fre(x):
  if x <= 1:
    return 3
  elif x <= 20:
    return 2
  else:
    return 1
#1의 값이 대부분이고 53회 등의 나머지 값을 한 그룹으로 묶고 그 사이의 값을 다른 그룹으로 묶었습니다.
df_user['frequency_score'] = df_user['frequency'].map(fre)

# %%
def rev(x):
  if x <= 9.800000e+04:
    return 1
  elif x <= 1.320000e+05:
    return 2
  elif x<= 1.980000e+05:
    return 3
  else:
    return 4

df_user['monetary_score'] = df_user['monetary'].map(rev)

# %%
df_user
# Out:
#        customer_id  recency  frequency  monetary  recency_score  \
# 0          72297.0       42          5    513310              4
# 1         478028.0      180          1     97500              1
# 2         478033.0      180          1     96000              1
# 3         469860.0      180          1    263000              1
# 4         478035.0      180          1     91000              1
# ...            ...      ...        ...       ...            ...
# 38073     545804.0        0          1   1800000              4
# 38074     669238.0        0          1    212000              4
# 38075     670891.0        0          1    159000              4
# 38076     640697.0        0          1     96000              4
# 38077     610626.0        0          1    139000              4
#
#        frequency_score  monetary_score
# 0                    2               4
# 1                    3               1
# 2                    3               1
# ...

# %%
#보통 RFM분석은 중요한 요소에 가중치를 두어 계산합니다. 보통...매출기여도에 가장 많이 기여한 요소에 높은 가중치를 둡니다만....
#이번 분석은 그냥 점수에 따라 고객을 분류하겠습니다.
#type1 초우량 고객 rfm이 모두 높음 -> vip제도를 통해 특별 대우
#type2 저수익성 고객 rf는 높지만 m이 낮음 -> 상품에 대한 관심은 많지만 구매를 망설이는 고객: 대부분의 마케팅 전략에서는 이들을 버리고 가는 방식을 취합니다.
#type3 신규고객rm은 높지만 f가 낮은 고객 -> 앞으로 성장할 가능성이 있는 고객, 상품에 대한 구매를 자극하여 우량고객으로 성장
#type4 이탈고객 fm은 높지만r이 낮은 고객 -> 예전에는 많이 이용했지만 지금은 이용하지 않는 고객, 재활성화를 위한 프로모션, 할인 서비스 등을 제공
#type5 - > 아직 정보를 충분히 얻지 못한 고객

# %%
def type(x,y,z):
  if x >= 3 and y>= 2 and z >= 3:
    return "type_1"
  elif x >= 2 and y >= 2 and z >= 2:
    return "type_2"
  elif x >= 2 and z >= 1 and y < 2:
    return "type_3"
  elif y >= 2 and z >= 1 and x >= 1:
    return "type_4"
  else:
    return "tyep_5"

# %%
df_user['customer_type'] = df_user.apply(lambda row: type(row['recency_score'], row['frequency_score'], row['monetary_score']), axis=1)

# %%
df_user
# Out:
#        customer_id  recency  frequency  monetary  recency_score  \
# 0          72297.0       42          5    513310              4
# 1         478028.0      180          1     97500              1
# 2         478033.0      180          1     96000              1
# 3         469860.0      180          1    263000              1
# 4         478035.0      180          1     91000              1
# ...            ...      ...        ...       ...            ...
# 38073     545804.0        0          1   1800000              4
# 38074     669238.0        0          1    212000              4
# 38075     670891.0        0          1    159000              4
# 38076     640697.0        0          1     96000              4
# 38077     610626.0        0          1    139000              4
#
#        frequency_score  monetary_score customer_type
# 0                    2               4        type_1
# 1                    3               1        type_4
# ...

# %%
df_user['customer_type'].value_counts()
# Out:
# type_4    14872
# type_1    12723
# type_2    10470
# type_3       13
# Name: customer_type, dtype: int64

# %%
avg_monetary = df_user.groupby('customer_type').monetary.agg(['mean','min','max'])
avg_monetary
# Out:
#                        mean     min      max
# customer_type
# type_1         2.683225e+05  132400  3070500
# type_2         1.613103e+05   98300  2482700
# type_3         2.233985e+06       0  7040750
# type_4         9.949579e+04       0  1738500

# %%
#고객 그룹별로 관심있는 분야를 알아내면 마케팅 전략을 짜는데 도움이 되지 않을꺼?
#관심있는 분야는 자주 구매한 분야로 정의내렸습니다.

# %%
df_o['category_title'].unique()
# Out:
# array(['프로그래밍', '영상/3D', '업무 생산성', '크리에이티브', '부동산/금융', '데이터사이언스', '디자인',
#        '마케팅', '교육', '투자/재테크', '관리', nan, '데이터 사이언스', '비즈니스', '지식콘텐츠',
#        '일러스트', '파이낸스'], dtype=object)

# %%
df_it = df_em = pd.DataFrame(df_ip, columns=['customer_id', 'category_title', 'completed_at'])
df_it
# Out:
#         customer_id category_title        completed_at
# 2           72297.0          프로그래밍 2021-03-28 15:21:43
# 4          478028.0         업무 생산성 2021-03-28 15:21:54
# 8          478033.0          영상/3D 2021-03-28 15:26:47
# 10         469860.0         부동산/금융 2021-03-28 15:27:17
# 14         478035.0          프로그래밍 2021-03-28 15:31:01
# ...             ...            ...                 ...
# 105411     669238.0            디자인 2021-09-25 13:39:26
# 105412     384003.0          영상/3D 2021-09-25 13:46:29
# 105413     670891.0          프로그래밍 2021-09-25 14:01:26
# 105416     640697.0          영상/3D 2021-09-25 14:17:41
# 105418     610626.0          영상/3D 2021-09-25 14:25:47
#
# [51179 rows x 3 columns]

# %%
df_it = pd.merge(df_it, df_user[['customer_id', 'customer_type']], on='customer_id')

# %%
df_it.head(10)
# Out:
#    customer_id category_title        completed_at customer_type
# 0      72297.0          프로그래밍 2021-03-28 15:21:43        type_1
# 1      72297.0          프로그래밍 2021-04-11 15:18:35        type_1
# 2      72297.0          영상/3D 2021-06-30 20:24:24        type_1
# 3      72297.0         업무 생산성 2021-06-30 20:29:12        type_1
# 4      72297.0         투자/재테크 2021-08-13 21:30:43        type_1
# 5     478028.0         업무 생산성 2021-03-28 15:21:54        type_4
# 6     478033.0          영상/3D 2021-03-28 15:26:47        type_4
# 7     469860.0         부동산/금융 2021-03-28 15:27:17        type_4
# 8     478035.0          프로그래밍 2021-03-28 15:31:01        type_4
# 9     478031.0        데이터사이언스 2021-03-28 15:33:28        type_4

# %%
df_ip.loc[df_ip['customer_id'] == 72297.0]
# Out:
#             id  customer_id  course_id     type      state  \
# 2       970657      72297.0   204246.0  PAYMENT  COMPLETED
# 11298  1004099      72297.0   203720.0  PAYMENT  COMPLETED
# 65792  1181420      72297.0   205162.0  PAYMENT  COMPLETED
# 65808  1181456      72297.0   204373.0  PAYMENT  COMPLETED
# 88388  1285179      72297.0   202789.0  PAYMENT  COMPLETED
#
#                                             course_title category_title  \
# 2                                   시크릿코드 : 프론트엔드 실무 완성편          프로그래밍
# 11298                        초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍
# 65792  올인원 패키지 : 아카데미 : 편집하는여자의 영상편집 마스터클래스 - 제 1강 프리...          영상/3D
# 65808                         초격차 패키지 : 일잘러 필수 스킬 모음.zip         업무 생산성
# 88388                   올인원 패키지 : 2021 취업/이직/투자를 위한 기업분석         투자/재테크
#
#        format        completed_at  transaction_amount           coupon_title  \
# 2      스쿨 온라인 2021-03-28 15:21:43              171810  [10% 할인] 시크릿코드 실무 완성편
# ...

# %%
#혹시 고객타입별로 선호하는 분야가 있지 않을까?
df_it['completed_at'] = df_it['completed_at'].dt.strftime('%Y-%m')

# %%
df_it
# Out:
#        customer_id category_title completed_at customer_type
# 0          72297.0          프로그래밍      2021-03        type_1
# 1          72297.0          프로그래밍      2021-04        type_1
# 2          72297.0          영상/3D      2021-06        type_1
# 3          72297.0         업무 생산성      2021-06        type_1
# 4          72297.0         투자/재테크      2021-08        type_1
# ...            ...            ...          ...           ...
# 51174     545804.0            디자인      2021-09        type_1
# 51175     669238.0            디자인      2021-09        type_1
# 51176     670891.0          프로그래밍      2021-09        type_1
# 51177     640697.0          영상/3D      2021-09        type_4
# 51178     610626.0          영상/3D      2021-09        type_1
#
# [51179 rows x 4 columns]

# %%
#고객타입별로 가장 관심있는 상위4개의 카테고리 구하기
customer_interest = df_it.groupby('customer_type')['category_title'].value_counts()

# %%
customer_interest
# Out:
# customer_type  category_title
# type_1         프로그래밍             6596
#                데이터사이언스           3133
#                디자인               2625
#                영상/3D             2025
#                마케팅               2006
#                업무 생산성            1609
#                부동산/금융            1381
#                투자/재테크            1128
#                크리에이티브             272
#                비즈니스                16
#                파이낸스                16
#                지식콘텐츠               10
# type_2         프로그래밍             3805
#                업무 생산성            2201
#                디자인               1604
#                영상/3D             1475
#                데이터사이언스           1429
#                마케팅               1273
#                부동산/금융             742
#                크리에이티브             213
#                투자/재테크             144
#                지식콘텐츠                9
#                데이터 사이언스             5
#                관리                   1
# ...

# %%
df_ci = pd.DataFrame(customer_interest)

# %%
df_ci
# Out:
#                               category_title
# customer_type category_title
# type_1        프로그래밍                     6596
#               데이터사이언스                   3133
#               디자인                       2625
#               영상/3D                     2025
#               마케팅                       2006
#               업무 생산성                    1609
#               부동산/금융                    1381
#               투자/재테크                    1128
#               크리에이티브                     272
#               비즈니스                        16
#               파이낸스                        16
#               지식콘텐츠                       10
# type_2        프로그래밍                     3805
#               업무 생산성                    2201
#               디자인                       1604
#               영상/3D                     1475
#               데이터사이언스                   1429
#               마케팅                       1273
#               부동산/금융                     742
# ...

# %%
df_ci.rename(columns={'category_title':'category_value'}, inplace = True) #데이터값에 따라 컬럼의 이름을 바꿔줍니다.

# %%
df_ci.reset_index(inplace=True) #데이터프레임에서 다중 인덱스로 설저된 부분을 바꿉니다.

# %%
df_ci
# Out:
#    customer_type category_title  category_value
# 0         type_1          프로그래밍            6596
# 1         type_1        데이터사이언스            3133
# 2         type_1            디자인            2625
# 3         type_1          영상/3D            2025
# 4         type_1            마케팅            2006
# 5         type_1         업무 생산성            1609
# 6         type_1         부동산/금융            1381
# 7         type_1         투자/재테크            1128
# 8         type_1         크리에이티브             272
# 9         type_1           비즈니스              16
# 10        type_1           파이낸스              16
# 11        type_1          지식콘텐츠              10
# 12        type_2          프로그래밍            3805
# 13        type_2         업무 생산성            2201
# 14        type_2            디자인            1604
# 15        type_2          영상/3D            1475
# 16        type_2        데이터사이언스            1429
# 17        type_2            마케팅            1273
# 18        type_2         부동산/금융             742
# ...

# %%
#각 타입별로 가장 많이 구매한 4개의 분야 고르기
df_top_4 = df_ci.sort_values('category_value', ascending=False).groupby('customer_type').head(4)

# %%
df_top_4
# Out:
#    customer_type category_title  category_value
# 0         type_1          프로그래밍            6596
# 35        type_4          프로그래밍            6356
# 12        type_2          프로그래밍            3805
# 1         type_1        데이터사이언스            3133
# 36        type_4         업무 생산성            2763
# 2         type_1            디자인            2625
# 37        type_4        데이터사이언스            2235
# 13        type_2         업무 생산성            2201
# 3         type_1          영상/3D            2025
# 38        type_4          영상/3D            1608
# 14        type_2            디자인            1604
# 15        type_2          영상/3D            1475
# 25        type_3          프로그래밍             133
# 26        type_3        데이터사이언스              62
# 27        type_3            디자인              52
# 28        type_3            마케팅              52

# %%
#보기 편하기 위해 고객 타입순으로, 각 그룹 내에서는 내림차순으로 정렬
df_top_4.sort_values(['customer_type', 'category_value'], ascending=[True, False])
# Out:
#    customer_type category_title  category_value
# 0         type_1          프로그래밍            6596
# 1         type_1        데이터사이언스            3133
# 2         type_1            디자인            2625
# 3         type_1          영상/3D            2025
# 12        type_2          프로그래밍            3805
# 13        type_2         업무 생산성            2201
# 14        type_2            디자인            1604
# 15        type_2          영상/3D            1475
# 25        type_3          프로그래밍             133
# 26        type_3        데이터사이언스              62
# 27        type_3            디자인              52
# 28        type_3            마케팅              52
# 35        type_4          프로그래밍            6356
# 36        type_4         업무 생산성            2763
# 37        type_4        데이터사이언스            2235
# 38        type_4          영상/3D            1608

# %%
#위의 결과를 통해 고객 분류에 상관없이 프로그래밍에 대한 관심도가 가장 높은 것으로 보아 프로그래밍 제품에 대해 마케팅 전략을 펼친다면 모든 고객에게 영향을 미칠것으로 예상됩니다.
#type4는 이탈고객으로 예전에 비해 현재 이용율이 높지 않은 그룹입니다. 이들의 관심을 끌기 위해 업무생산성이나 데이터 사이언스 부분에 대한 프로모션이나 할인쿠폰등을 이용하면 
#이들의 관심을 끌 수 있을 것입니다.
#데이터 사이언스 부문에 대한 마케팅 전략은 앞으로 우량고객이 될 수 있는 type3의 관심사와도 겹치기 때문에 효과적일 것입니다.

# %% [markdown]
# # Summary & Conclusion

# %% [markdown]
#     - 이런 걸 확인 할 수 있었다 위주(모든 EDA가 유의미한 결과가 있는 것은 아니므로)
#     - 과정 중 어려웠거나 도전적인 부분 있었다면 기술 및 해결여부 확인(그냥 포기했는지, 어떤 방법으로 완수했는지)
#     - 시간이 더 주어진다면 향후 계획
#         - 추가적으로 해볼 수 있다면 ? : 고객 customer_id 에 대한 샘플링 및 분석
#
# ### 새롬님 raw summary
# 요약
# 개인 고객을 분석하기 위해 RFM분석 방법을 사용하여 비슷한 특징을 가진 고객끼리 분류하여 효율적인 마케팅 방법을 찾고자 함.
# 분석한 결과로 고객 분류에 상관없이 프로그래밍에 대한 관심도가 가장 높은 것으로 보아 프로그래밍제품을 대상으로 한 마케팅 전략은 모든 고객에게 영향을 미칠 것입니다. 이탈고객의 구매를 재활성화 시키기 위해서는 이들이 관심있었던 업무생산성이나 데이터 사이언스 부분에 대한 프로모션이나 할인쿠폰 등을 이용하면 효과적일 것입니다. 특히 데이터 사이언스 부분에 대한 마케팅 전략은 신규고객 역시 관심이 있는 분야이기 때문에 다른 분야보다 더 효율적인 마케팅이 가능할 것으로 보입니다.
#
# ### 참고
# RFM분석
# 고객의 최근성(어떤 고객이 최근에 구매한 고객인가), 고객의 구매빈도, 고객의 구매금액에 따른 고객의 타입을 나눠 효율적인 고객관리를 위한 분석방법
# 자료에서는 마지막 구매일자(9월 25일)을 바탕으로 고객별 최근 구매일을 구하여 최근성을 구하고, 고객의 구매일을 기반으로 구매 빈도를 구하고, 거래금액을 바탕으로 고객의 구매 금액을 구하였습니다.
# Type1
# 초우량 고객으로 모든 요소의 점수가 높은 고객입니다. vip제도를 통해 특별대우를 해줌으로서 이들의 충성심을 제고할 수 있습니다.
# Type2
# 저수익성 고객으로 상대적으로 구매금액이 낮은 고객입니다. 전통적인 마케팅 전략에서는 이들이 큰 수익이 되지 않는다고 여겨 이들을 대상으로 마케팅 전략을 펼치지 않습니다.
# Type3
# 신규고객으로 상대적으로 구매빈도가 낮은 고객입니다. 이들의 수요를 자극하게 되면 우량고객으로 성장할 가능성이 높습니다.
# Type4
# 이탈고객으로 상대적으로 최근성이 낮은 고객입니다. 이전에는 이용하였지만 어떤 이유로 지금은 이용하지 않는 고객으로 구매 재활성화를 위한 프로모션, 할인 서비스 등을 제공합니다.
